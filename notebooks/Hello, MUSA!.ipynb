# %% [markdown]
# # Hello, MUSA!

# %%
import rasterio
from PIL import Image

# %%
with rasterio.open('/home/hadoop/data/CDLS_2016_30m-Philly.tif') as ds:
    data = ds.read()[0]

# %%
img = Image.fromarray(data, 'L')

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=803x1119 at 0x7F5E9D7D4278>
